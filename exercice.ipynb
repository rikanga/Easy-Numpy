# %% [markdown]
# <a href="https://colab.research.google.com/github/rikanga/Easy-Numpy/blob/main/exercice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np, matplotlib.pyplot as plt

# %%
x = np.random.random((100, 1))
xx = np.random.normal(size=(100, 1)) / 10
y = x*x + xx * xx

# %%
fig, ax = plt.subplots()
ax.plot(x, y, 'b*', label='data')
ax.set_title('Nuage des points')
plt.legend()
plt.show()

# %% [markdown]
# ## **Model**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %%
linear = LinearRegression().fit(x, y)
tree = DecisionTreeRegressor(max_depth=4).fit(x, y)

# %%
linear_pred = linear.predict(x)
tree_pred = tree.predict(x)

# %%
fig, ax = plt.subplots()
plt.plot(x, y, 'ob', label='data')
plt.plot(x, linear_pred, '^r', label='linear')
plt.plot(x, tree_pred, 'vy', label='tree')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
#ax.plot(x, y, 'ob', label='data')
ax.plot(x, linear_pred, '^r', label='linear')
ax.plot(x, tree_pred, 'vy', label='tree')
erreur = [np.min(y), np.max(y)]
ax.plot(erreur, erreur, '--g', label='erreur')
ax.set_xlabel('Y attendu')
ax.set_ylabel('Y prédit')
ax.legend()
plt.show()
